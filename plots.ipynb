# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/income.csv')

# %%
df.plot()

# %%
sns.lineplot(x=df.index, y=df.income)

# %%
plt.plot(df.index, df.income)

# %%
df.plot(kind='line')

# %%
df.income.plot()

# %%
sns.lineplot(data=df)

# %%
df = pd.read_csv('dataset_209770_6.txt', sep=' ')

# %%
df
# Out:
#               x            y
# 0    401.722298   804.988361
# 1    906.526588  1294.997096
# 2    886.025953  1302.573525
# 3    390.520199   809.368766
# 4    392.094610   816.050066
# 5   1192.421692   593.543958
# 6   1196.620622   600.453069
# 7   1201.382476   585.023367
# 8    813.728812   204.719392
# 9    996.389992   694.928746
# 10   907.688580  1309.023670
# 11   813.878829   186.511048
# 12   301.959403  1490.818665
# 13   797.132076   193.665026
# 14   783.927887   203.897766
# 15   488.168524   504.946866
# 16   392.743999   798.106458
# 17  1293.066001   287.394210
# 18  1291.239179   286.480197
# 19   308.246117  1512.407289
# 20   990.600912   699.507016
# 21   514.848467   507.776222
# 22   812.669830   211.763542
# 23   397.688610   795.952877
# 24   390.823999   797.769397
# 25   304.815810  1490.104174
# 26   316.372651  1501.466753
# 27   984.276599   689.819599
# 28   493.109351   503.266252
# 29   304.970609  1489.781097
# ..          ...          ...
# ...

# %%
sns.scatterplot(x='x', y='y', data=df)

# %%
genome_data = pd.read_csv('https://stepik.org/media/attachments/course/4852/genome_matrix.csv',  index_col = 0)

# %%
genome_data
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
map = sns.heatmap(genome_data, cmap='viridis')
map.xaxis.set_ticks_position('top')
map.xaxis.set_tick_params(rotation=90)

# %%
dota_dataset = pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv', converters={'roles': lambda x: x[1:-1].count(',')+1})

# %%
dota_dataset
# Out:
#      Unnamed: 0 attack_type   id  legs       localized_name  \
# 0             0       Melee    1     2            Anti-Mage
# 1             1       Melee    2     2                  Axe
# 2             2      Ranged    3     4                 Bane
# 3             3       Melee    4     2          Bloodseeker
# 4             4      Ranged    5     2       Crystal Maiden
# 5             5      Ranged    6     2          Drow Ranger
# 6             6       Melee    7     2          Earthshaker
# 7             7       Melee    8     2           Juggernaut
# 8             8      Ranged    9     2               Mirana
# 9             9      Ranged   10     0            Morphling
# 10           10      Ranged   11     0         Shadow Fiend
# 11           11       Melee   12     2       Phantom Lancer
# 12           12      Ranged   13     2                 Puck
# 13           13       Melee   14     2                Pudge
# 14           14      Ranged   15     0                Razor
# ...

# %%
dota_dataset.roles.hist()

# %%
flowers_dataset = pd.read_csv('https://stepik.org/media/attachments/course/4852/iris.csv').drop(['Unnamed: 0'], axis=1)

# %%
flowers_dataset
# Out:
#      sepal length  sepal width  petal length  petal width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# 5             5.4          3.9           1.7          0.4        0
# 6             4.6          3.4           1.4          0.3        0
# 7             5.0          3.4           1.5          0.2        0
# 8             4.4          2.9           1.4          0.2        0
# 9             4.9          3.1           1.5          0.1        0
# 10            5.4          3.7           1.5          0.2        0
# 11            4.8          3.4           1.6          0.2        0
# 12            4.8          3.0           1.4          0.1        0
# ...

# %%
for column in flowers_dataset:
    sns.kdeplot(flowers_dataset[column])

# %%
sns.violinplot(flowers_dataset['petal length'], orient='v')

# %%
flowers_dataset.species = flowers_dataset.species.map({0: 'x', 1: 'y', 2: 'z'})
sns.pairplot(flowers_dataset, hue='species')
