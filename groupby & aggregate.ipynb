# %%
import pandas as pd
import numpy as np

# %%
dota_dataset = pd.read_csv("https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv")

# %%
dota_dataset.groupby('legs').id.nunique()
# Out:
# legs
# 0    11
# 2    95
# 4     7
# 6     3
# 8     1
# Name: id, dtype: int64

# %%
dota_dataset
# Out:
#      Unnamed: 0 attack_type   id  legs       localized_name  \
# 0             0       Melee    1     2            Anti-Mage
# 1             1       Melee    2     2                  Axe
# 2             2      Ranged    3     4                 Bane
# 3             3       Melee    4     2          Bloodseeker
# 4             4      Ranged    5     2       Crystal Maiden
# 5             5      Ranged    6     2          Drow Ranger
# 6             6       Melee    7     2          Earthshaker
# 7             7       Melee    8     2           Juggernaut
# 8             8      Ranged    9     2               Mirana
# 9             9      Ranged   10     0            Morphling
# 10           10      Ranged   11     0         Shadow Fiend
# 11           11       Melee   12     2       Phantom Lancer
# 12           12      Ranged   13     2                 Puck
# 13           13       Melee   14     2                Pudge
# 14           14      Ranged   15     0                Razor
# ...

# %%
salary_dataset = pd.read_csv('https://stepik.org/media/attachments/course/4852/accountancy.csv')

# %%
salary_dataset.groupby(['Executor', 'Type']).aggregate({'Salary': 'max'})
# Out:
#                Salary
# Executor Type
# Loopa    A         58
#          B        249
#          C        249
#          D        181
#          E        220
#          F        244
# Pupa     A        234
#          B         77
#          C         94
#          D        194
#          E        197
#          F        195

# %%
dota_dataset.groupby(['attack_type', 'primary_attr']).id.nunique()
# Out:
# attack_type  primary_attr
# Melee        agi             19
#              int              2
#              str             35
# Ranged       agi             18
#              int             40
#              str              3
# Name: id, dtype: int64

# %%
dota_dataset.groupby(['attack_type', 'primary_attr']).id.nunique().sort_values()
# Out:
# attack_type  primary_attr
# Melee        int              2
# Ranged       str              3
#              agi             18
# Melee        agi             19
#              str             35
# Ranged       int             40
# Name: id, dtype: int64

# %%
concentrations = pd.read_csv('http://stepik.org/media/attachments/course/4852/algae.csv')

# %%
mean_concentrations = concentrations.groupby('genus')

# %%
concentrations.loc[concentrations.genus == 'Fucus']
# Out:
#              species  genus  group   sucrose    alanin   citrate   glucose  \
# 0  Fucus_vesiculosus  Fucus  brown  3.001472  3.711498  5.004262  2.548459
# 2     Fucus_serratus  Fucus  brown  3.276870  0.346431  1.216767  3.623225
# 3    Fucus_distichus  Fucus  brown  6.786996  6.641303  6.423606  2.272724
#
#    oleic_acid
# 0    6.405165
# 2    0.304573
# 3    3.393203

# %%
mean_concentrations.agg(['min', 'mean', 'max']).loc['Fucus', 'alanin'].round(2)
# Out:
# min     0.35
# mean    3.57
# max     6.64
# Name: Fucus, dtype: float64

# %%
concentrations.groupby('group').aggregate(['count', 'var', np.ptp])
# Out:
# c:\users\dan_an\appdata\local\programs\python\python37-32\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
#       sucrose                     alanin                     citrate  \
#         count       var       ptp  count       var       ptp   count
# group
# brown       6  5.459098  5.189345      6  7.220351  6.294872       6
# green       3  2.672626  3.259662      3  7.059917  5.232574       3
# red         1       NaN  0.000000      1       NaN  0.000000       1
#
#                           glucose                     oleic_acid            \
#             var       ptp   count       var       ptp      count       var
# group
# brown  5.468942  5.351686       6  1.767756  3.740495          6  4.385233
# green  3.950113  3.857763       3  0.266265  1.026753          3  0.540388
# ...
